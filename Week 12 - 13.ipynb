# %%
# Exercise 1 : Identifying and Handling Missing Data
import pandas as pd 

# Sample dataset with missing values
data = {
    'Name' : ['Alice', 'Bob', 'Charlie', 'David', None],
    'Age' : [24, 30, None, 22, 35],
    'Salary' : [48000, None, 57000, None, 60000]
}

df = pd.DataFrame(data)

# Filling missing values and dropping rows
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
df.dropna(subset=['Name'], inplace=True)
print('After cleaning: \n', df)
# Out:
# After cleaning:
#        Name    Age   Salary
# 0    Alice  24.00  48000.0
# 1      Bob  30.00  57000.0
# 2  Charlie  27.75  57000.0
# 3    David  22.00  57000.0
# /tmp/ipykernel_8085/119795742.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# /tmp/ipykernel_8085/119795742.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(), inplace=True)

# %%
# Exercise 2: Standardizing Categorical Data
# Sample dataset with inconsistent categorical values
data = {
    'Product': ['Laptop', 'Laptop', 'Desktop', 'Tablet', 'Tablet'],
    'Category': ['Electronics', 'electronics', 'Electronics', 'Gadgets', 'gadgets']
}
df = pd.DataFrame(data)

# Standardize category values
df['Category'] = df['Category'].str.capitalize()
print('Standardized Data:\n', df)
# Out:
# Standardized Data:
#     Product     Category
# 0   Laptop  Electronics
# 1   Laptop  Electronics
# 2  Desktop  Electronics
# 3   Tablet      Gadgets
# 4   Tablet      Gadgets

# %%
# Practice Task Week 12
# - Load a dataset of your choice and identify missing values.
# - Implement data transformations to normalize numerical columns.
# - Standardize categorical columns and remove duplicates.

import pandas as pd

# Sample dataset with missing values
data = {
    'Name' : ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age' : [24, 30, None, 22, 35],
    'Salary' : [48000, None, 57000, None, 60000],
    'Department' : ['HR', 'IT', 'HR', 'Finance', 'Finance']
}

df = pd.DataFrame(data)

print("Jumlah data yang hilang pada setiap kolom:\n", df.isnull().sum())
# Out:
# Jumlah data yang hilang pada setiap kolom:
#  Name          0
# Age           1
# Salary        2
# Department    0
# dtype: int64

# %%
# Fill missing values
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# Min-Max Scaling
df['Age-Normalized'] = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())
df['Salary-Normalized'] = (df['Salary'] - df['Salary'].min()) / (df['Salary'].max() - df['Salary'].min())

print("\nAfter normalization:\n", df[['Name', 'Age', 'Age-Normalized', 'Salary', 'Salary-Normalized']])
# Out:
# After normalization:
#        Name    Age  Age-Normalized   Salary  Salary-Normalized
# 0    Alice  24.00        0.153846  48000.0               0.00
# 1      Bob  30.00        0.615385  57000.0               0.75
# 2  Charlie  27.75        0.442308  57000.0               0.75
# 3    David  22.00        0.000000  57000.0               0.75
# 4      Eve  35.00        1.000000  60000.0               1.00

# %%
# Standardize text values in the 'Department' column
df['Department'] = df['Department'].str.upper()

# Remove duplicates
df = df.drop_duplicates(subset=['Department'])

print("\nAfter standardizing and removing duplicates:\n", df[['Name', 'Department']])
# Out:
# After standardizing and removing duplicates:
#      Name Department
# 0  Alice         HR
# 1    Bob         IT
# 3  David    FINANCE

# %% [markdown]
# Pertemuan 13

# %%
# Exercise 1: Basic Plotting with Matplotlib
import matplotlib.pyplot as plt

# Data for plotting
categories = ['Category A', 'Category B', 'Category C']
values = [23, 17, 35]

# Plot
plt.figure(figsize=(8, 5))
plt.bar(categories, values, color='deepskyblue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart of Categories')
plt.show()

# %%
# Exercise 2: Seaborn for Relationship Visualization
import seaborn as sns
import pandas as pd

# Sample data
data = {
    'Hours Studied': [2, 4, 6, 8, 10],
    'Scores': [45, 52, 60, 68, 78]
}
df = pd.DataFrame(data)

# Plot
sns.regplot(x='Hours Studied', y='Scores', data=df)
plt.title('Relationship between Hours Studied and Scores')
plt.show()

# %% [markdown]
# Practice

# %% [markdown]
# Use Matplotlib to Create a Multi-Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['A', 'B', 'C', 'D']
group1 = [20, 34, 30, 35]
group2 = [25, 32, 34, 20]
group3 = [22, 30, 32, 25]

x = np.arange(len(categories))  # Label locations
width = 0.25  # Width of the bars

# Create the multi-bar chart
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(x - width, group1, width, label='Group 1', color='skyblue')
ax.bar(x, group2, width, label='Group 2', color='orange')
ax.bar(x + width, group3, width, label='Group 3', color='green')

# Add labels, title, and legend
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Comparison of Groups by Categories')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %% [markdown]
# Generate Scatter Plots with Seaborn

# %%
import seaborn as sns
import pandas as pd

# Sample dataset
data = {
    'Age': [22, 25, 30, 35, 40, 28, 33, 24],
    'Salary': [25000, 27000, 30000, 35000, 40000, 32000, 37000, 26000],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'Finance', 'HR', 'Finance', 'IT']
}

df = pd.DataFrame(data)

# Create scatter plot
plt.figure(figsize=(8, 6))
scatter = sns.scatterplot(
    data=df,
    x='Age',
    y='Salary',
    hue='Department',
    style='Department',
    palette='Set2',
    s=100  # Size of markers
)

# Customize the plot
scatter.set_title('Scatter Plot: Age vs Salary by Department')
scatter.set_xlabel('Age')
scatter.set_ylabel('Salary')
plt.legend(title='Department')
plt.show()

# %% [markdown]
# Customize Plot Layouts and Color Schemes

# %%
# Create a customized scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=df,
    x='Age',
    y='Salary',
    hue='Department',
    palette='coolwarm',
    s=120
)

# Add grid, title, and labels
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.title('Customized Scatter Plot: Age vs Salary', fontsize=16, fontweight='bold')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend(title='Department', fontsize=10, title_fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Homework

# %% [markdown]
# Week 12

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('CarsDataset.csv')

# Menghapus baris dengan nilai kosong
df_clean = df.dropna().reset_index(drop=True)
df.dropna(subset=['Color'], inplace=True)

# Bersihkan nama kolom dari spasi ekstra
df_clean.columns = df_clean.columns.str.strip()

# Ubah kolom 'Km/h' dan 'Price' dari string ke numerik (hapus koma)
df_clean['Km/h'] = df_clean['Km/h'].str.replace(',', '').astype(float)
df_clean['Price'] = df_clean['Price'].str.replace(',', '').astype(float)

# Tampilkan data yang sudah dibersihkan
# 47                   Subaru XV  2017  190000.0       Blue  Automatic
# 48                     BMW 116  2009  270000.0        Red  Automatic
# 49          Hyundai Tucson GDI  2019   95000.0      White  Automatic
# 50                        MG 5  2021  106000.0     Silver  Automatic
# 51                      BYD L3  2022  165000.0     Silver  Automatic
# 52                KIA Sporatge  2020   85000.0  Dark Blue  Automatic
# 53          Hyundai Elantra HD  2017  145000.0     Silver  Automatic
# 54                 KIA Picanto  2015   70000.0     Silver  Automatic
# 55  Mitsubishi Lancer EX Shark  2015  120000.0      Black  Automatic
# 56           Ssang Yong Torres  2024    4000.0      White  Automatic
# 57                  KIA Cerato  2011  200000.0        Red  Automatic
# 58          Hyundai Elantra HD  2020   80000.0     Bronze  Automatic
#
#         Fuel      Price
# 0   Gasoline   850000.0
# 1     Hybrid  2270000.0
# 2   Gasoline  3260000.0
# 3   Gasoline  1270000.0
# 4   Gasoline  5700000.0
# 5   Gasoline  1525000.0
# 6   Gasoline  1500000.0
# 7   Gasoline  1800000.0
# 8   Gasoline  1950000.0
# 9   Gasoline   990000.0
# 10  Gasoline  4400000.0
# 11  Gasoline  4000000.0
# 12  Gasoline   955000.0
# 13  Gasoline  1720000.0
# 14  Gasoline  1700000.0
# 15  Gasoline  5500000.0
# 16  Gasoline  1400000.0
# 17  Gasoline  6000000.0
# 18  Gasoline  1400000.0
# 19  Gasoline  3800000.0
# 20  Gasoline  2950000.0
# 21  Gasoline   760000.0
# 22  Gasoline  1300000.0
# 23  Gasoline  2380000.0
# 24  Gasoline  1650000.0
# 25  Gasoline   950000.0
# 26  Gasoline  1190000.0
# 27  Gasoline   500000.0
# 28  Gasoline   860000.0
# 29  Gasoline  1550000.0
# 30  Gasoline  1070000.0
# 31  Gasoline   715000.0
# 32  Gasoline  4000000.0
# 33  Gasoline   760000.0
# 34  Gasoline   445000.0
# 35  Gasoline   675000.0
# 36  Gasoline   795000.0
# 37  Gasoline   150000.0
# 38  Gasoline   680000.0
# 39  Gasoline   840000.0
# 40  Gasoline   930000.0
# 41  Gasoline   970000.0
# 42  Gasoline   395000.0
# 43  Gasoline  1085000.0
# 44  Gasoline  1145000.0
# 45  Gasoline   945000.0
# 46  Gasoline  1000000.0
# 47  Gasoline  1000000.0
# 48  Gasoline   660000.0
# 49  Gasoline  1440000.0
# 50  Gasoline   755000.0
# 51  Gasoline   510000.0
# 52  Gasoline  1570000.0
# 53  Gasoline   675000.0
# 54  Gasoline   535000.0
# 55  Gasoline   660000.0
# 56  Gasoline  1900000.0
# 57  Gasoline   665000.0
# 58  Gasoline   700000.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribusi harga mobil
plt.figure(figsize=(10, 6))
sns.histplot(df_clean['Price'], bins=30, kde=True)
plt.title('Distribusi Harga Mobil')
plt.xlabel('Harga')
plt.show()

# Scatter plot antara Tahun dan Harga
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x='Year', y='Price', hue='Fuel')
plt.title('Harga Mobil Berdasarkan Tahun')
plt.xlabel('Tahun')
plt.ylabel('Harga')
plt.show()
